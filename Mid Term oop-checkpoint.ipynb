# %%
import random
class Team():
    def get_data(self):
        self.team1 = {}
        self.team2 = {}
        print("**************************************************************************************************")
        for i in range(0,3):
            ask1,ask2 = input("Team1 Enter player name and his role like Batsman/Bowler/Allrounder comma seprated ").split(",")
            self.team1[ask1] = ask2
        print("---------------------------------------------------------------------------------------------------")
        for i in range(0,3):
            ask1,ask2 = input("Team2 Enter player name and his role like Batsman/Bowler/Allrounder comma seprated ").split(",")
            self.team2[ask1] = ask2
        print("**************************************************************************************************")
        
class Match(Team):
    def mom1(self):
        for i,v in self.player_maxwickets.items():
            for c,d in self.player_maxscore.items():
                if v[0] >=(len(self.team1)/2) and d[0]<100:
                    self.mom.append(i)
                elif v[0]<(len(self.team1)/2) and d[0]>=100:
                    self.mom.append(c)
                elif v[0]>(len(self.team1)/2) and d[0]>=100:
                    self.mom.append(i)
                elif v[0]<(len(self.team1)/2) and d[0]>=50:
                    self.mom.append(c)
                elif v[0] == 3 and d[0]<50:
                    self.mom.append(i)
                else:
                    self.mom.append(c)
    def match1(self):
        super(Match,self).get_data()
        toss = input("Team 1 what you want to choose for toss Heads of Tails ")
        print("---------------------------------------------------------------------------------------------------")
        if random.choice(("h","t")) == toss[0].lower():
            print(f"Its {toss} Team 1 won the toss")
            ask2 = input("Enter whats you wnat to do Bat/Bowl ")
            print("---------------------------------------------------------------------------------------------------")
            if ask2[0:3].lower() == "bat" :
                print("Team 1 is Batting First")
                self.team1_score = {}
                self.team1_wickets_takes = {}
                for i in self.team1.keys():
                    score1 = int(input(f"Enter score of Team 1 {i} "))
                    self.team1_score[i] = score1 
                print("---------------------------------------------------------------------------------------------------")
                for i,v in self.team1.items():
                    if v[:4].lower() == "bowl":
                        wickets = int(input(f"Enter No of wickets of Team1 {i} takes "))
                        self.team1_wickets_takes[i] = wickets
                self.total_wickets_loss1 = int(input("How many Wickets team1 loss after batting : "))
                self.total_over1 = int(input("In How many overs team 1 cover this target after batting : "))
                self.total_run1 = sum(self.team1_score.values())
                print("**************************************************************************************************")
                self.team2_score = {}
                self.team2_wickets_takes = {}
                for i in self.team2.keys():
                    score1 = int(input(f"Enter score of Team 2 {i} "))
                    self.team2_score[i] = score1 
                print("---------------------------------------------------------------------------------------------------")
                for i,v in self.team2.items():
                    if v[:4].lower() == "bowl":
                        wickets = int(input(f"Enter No of wickets of Team2 {i} takes "))
                        self.team2_wickets_takes[i] = wickets
                self.total_wickets_loss2 = sum(self.team1_wickets_takes.values())
                self.total_over2 = int(input("In How many overs team 2 cover this target after batting : "))
                self.total_run2 = sum(self.team2_score.values())
                if self.total_run1> self.total_run2 :
                    print("Team 1 win")
                    self.mom = []
                    self.player_maxscore = {}
                    self.player_maxwickets = {}
                    for i,v in self.team1_wickets_takes.items():
                        if v == max(self.team1_wickets_takes.values()):
                            self.player_maxwickets[i]  = [v]
                    for i,v in self.team1_score.items():
                        if v == max(self.team1_score.values()):
                            self.player_maxscore[i]  = [v]
                    self.mom1()
                    w=1
                    return w,self.mom[0],self.player_maxscore,self.player_maxwickets,self.total_run1,self.total_wickets_loss1,self.total_over1
                elif self.total_run1<self.total_run2: 
                    print("Team 2 win")
                    self.player_maxwickets = {}
                    self.player_maxscore = {}
                    self.mom = []
                    for i,v in self.team2_wickets_takes.items():
                        if v == max(self.team2_wickets_takes.values()):
                            self.player_maxwickets[i]  = [v]
                    for i,v in self.team2_score.items():
                        if v == max(self.team2_score.values()):
                            self.player_maxscore[i]  = [v]
                    self.mom1()
                    w=2
                    return w,self.mom[0],self.player_maxscore,self.player_maxwickets,self.total_run2,self.total_wickets_loss2,self.total_over2
                else:
                    print("Match is Draw")
            else:
                print("Team1 opted to Bowl Frist")
                print("---------------------------------------------------------------------------------------------------")
                print("Team 2 is batting first")
                self.team2_score = {}
                self.team2_wickets_takes = {}
                for i in self.team2.keys():
                    score1 = int(input(f"Enter score of Team 2 {i} "))
                    self.team2_score[i] = score1 
                print("---------------------------------------------------------------------------------------------------")
                for i,v in self.team2.items():
                    if v[:4].lower() == "bowl":
                        wickets = int(input(f"Enter No of wickets of Team2 {i} takes "))
                        self.team2_wickets_takes[i] = wickets
                self.total_wickets_loss2 = int(input("How many Wickets team2 loss after batting : "))
                self.total_over2 = int(input("In How many overs team 2 cover this target after batting : "))
                self.total_run2 = sum(self.team2_score.values())
                print("**************************************************************************************************")
                self.team1_score = {}
                self.team1_wickets_takes = {}
                for i in self.team1.keys():
                    score1 = int(input(f"Enter score of Team 1 {i} "))
                    self.team1_score[i] = score1 
                print("---------------------------------------------------------------------------------------------------")
                for i,v in self.team1.items():
                    if v[:4].lower() == "bowl":
                        wickets = int(input(f"Enter No of wickets of Team1 {i} takes "))
                        self.team1_wickets_takes[i] = wickets
                self.total_wickets_loss1 = sum(self.team2_wickets_takes.values())
                self.total_over1 = int(input("In How overs many team 1 cover this target after batting : "))
                self.total_run1 = sum(self.team1_score.values())
                if self.total_run1> self.total_run2 :
                    print("Team 1 win")
                    self.mom = []
                    self.player_maxscore = {}
                    self.player_maxwickets = {}
                    for i,v in self.team1_wickets_takes.items():
                        if v == max(self.team1_wickets_takes.values()):
                            self.player_maxwickets[i]  = [v]
                    for i,v in self.team1_score.items():
                        if v == max(self.team1_score.values()):
                            self.player_maxscore[i]  = [v]
                    self.mom1()
                    w=1
                    return w,self.mom[0],self.player_maxscore,self.player_maxwickets,self.total_run1,self.total_wickets_loss1,self.total_over1
                elif self.total_run1<self.total_run2: 
                    print("Team 2 win")
                    self.player_maxwickets = {}
                    self.player_maxscore = {}
                    self.mom = []
                    player_maxscore = {}
                    player_maxwickets = {}
                    for i,v in self.team2_wickets_takes.items():
                        if v == max(self.team2_wickets_takes.values()):
                            self.player_maxwickets[i]  = [v]
                    for i,v in self.team2_score.items():
                        if v == max(self.team2_score.values()):
                            self.player_maxscore[i]  = [v]
                    self.mom1()
                    w=2
                    return w,self.mom[0],self.player_maxscore,self.player_maxwickets,self.total_run2,self.total_wickets_loss2,self.total_over2
                else:
                    print("Match is Draw")
        else:
            print(f"its {toss} Team 2 Won the toss")
            ask2 = input("Enter whats you wnat to do Bat/Bowl ")
            print("---------------------------------------------------------------------------------------------------")
            if ask2[0:3].lower() == "bat" :
                print("Team 2 is Batting First")
                self.team2_score = {}
                self.team2_wickets_takes = {}
                for i in self.team2.keys():
                    score1 = int(input(f"Enter score of Team 2 {i} "))
                    self.team2_score[i] = score1 
                print("---------------------------------------------------------------------------------------------------")
                for i,v in self.team2.items():
                    if v[:4].lower() == "bowl":
                        wickets = int(input(f"Enter No of wickets of Team2 {i} takes "))
                        self.team2_wickets_takes[i] = wickets
                self.total_wickets_loss2 = int(input("How many Wickets team2 loss after batting : "))
                self.total_over2 = int(input("In How many overs team 2 cover this target after batting : "))
                self.total_run2 = sum(self.team2_score.values())
                print("**************************************************************************************************")
                print("Team 1 is batting")
                self.team1_score = {}
                self.team1_wickets_takes = {}
                for i in self.team1.keys():
                    score1 = int(input(f"Enter score of Team 1 {i} "))
                    self.team1_score[i] = score1 
                print("---------------------------------------------------------------------------------------------------")
                for i,v in self.team1.items():
                    if v[:4].lower() == "bowl":
                        wickets = int(input(f"Enter No of wickets of Team1 {i} takes "))
                        self.team1_wickets_takes[i] = wickets
                self.total_wickets_loss1 = sum(self.team2_wickets_takes.values())
                self.total_over1 = int(input("In How many over team 1 cover this target after batting : "))
                self.total_run1 = sum(self.team1_score.values())
                if self.total_run1> self.total_run2 :
                    print("Team 1 win")
                    self.player_maxwickets = {}
                    self.player_maxscore = {}
                    self.mom = []
                    for i,v in self.team1_wickets_takes.items():
                        if v == max(self.team1_wickets_takes.values()):
                            self.player_maxwickets[i]  = [v]
                    for i,v in self.team1_score.items():
                        if v == max(self.team1_score.values()):
                            self.player_maxscore[i]  = [v]
                    self.mom1()
                    w=1
                    return w,self.mom[0],self.player_maxscore,self.player_maxwickets,self.total_run1,self.total_wickets_loss1,self.total_over1
                elif self.total_run1<self.total_run2: 
                    print("Team 2 win")
                    self.player_maxwickets = {}
                    self.player_maxscore = {}
                    self.mom = []
                    for i,v in self.team2_wickets_takes.items():
                        if v == max(self.team2_wickets_takes.values()):
                            self.player_maxwickets[i]  = [v]
                    for i,v in self.team2_score.items():
                        if v == max(self.team2_score.values()):
                            self.player_maxscore[i]  = [v]
                    self.mom1()
                    w=2
                    return w,self.mom[0],self.player_maxscore,self.player_maxwickets,self.total_run2,self.total_wickets_loss2,self.total_over2
                else:
                    print("Match is Draw")
                
            else:
                print("Team 2 opted to Bowl Frist")
                print("---------------------------------------------------------------------------------------------------")
                print("Team 1 is batting")
                self.team1_score = {}
                self.team1_wickets_takes = {}
                for i in self.team1.keys():
                    score1 = int(input(f"Enter score of Team 1 {i} "))
                    self.team1_score[i] = score1 
                print("---------------------------------------------------------------------------------------------------")
                for i,v in self.team1.items():
                    if v[:4].lower() == "bowl":
                        wickets = int(input(f"Enter No of wickets of Team1 {i} takes "))
                        self.team1_wickets_takes[i] = wickets
                self.total_wickets_loss1 = int(input("How many Wickets team1 loss after batting : "))
                self.total_over1 = int(input("In How many overs team 1 cover this target after batting : "))
                self.total_run1 = sum(self.team1_score.values())
                print("**************************************************************************************************")
                print("Team 2 is Batting")
                self.team2_score = {}
                self.team2_wickets_takes = {}
                for i in self.team2.keys():
                    score1 = int(input(f"Enter score of Team 2 {i} "))
                    self.team2_score[i] = score1 
                print("---------------------------------------------------------------------------------------------------")
                for i,v in self.team2.items():
                    if v[:4].lower() == "bowl":
                        wickets = int(input(f"Enter No of wickets of Team2 {i} takes "))
                        self.team2_wickets_takes[i] = wickets
                self.total_wickets_loss2 = sum(self.team1_wickets_takes.values())
                self.total_over2 = int(input("In How many overs team 2 cover this target after batting : "))
                self.total_run2 = sum(self.team2_score.values())
                if self.total_run1> self.total_run2 :
                    print("Team 1 win")
                    self.player_maxwickets = {}
                    self.player_maxscore = {}
                    self.mom = []
                    for i,v in self.team1_wickets_takes.items():
                        if v == max(self.team1_wickets_takes.values()):
                            self.player_maxwickets[i]  = [v]
                    for i,v in self.team1_score.items():
                        if v == max(self.team1_score.values()):
                            self.player_maxscore[i]  = [v]
                    self.mom1()
                    w=1
                    return w,self.mom[0],self.player_maxscore,self.player_maxwickets,self.total_run1,self.total_wickets_loss1,self.total_over1
                elif self.total_run1<self.total_run2: 
                    print("Team 2 win")
                    self.player_maxwickets = {}
                    self.player_maxscore = {}
                    self.mom = []
                    for i,v in self.team2_wickets_takes.items():
                        if v == max(self.team2_wickets_takes.values()):
                            self.player_maxwickets[i]  = [v]
                    for i,v in self.team2_score.items():
                        if v == max(self.team2_score.values()):
                            self.player_maxscore[i]  = [v]
                    self.mom1()
                    w=2
                    return w,self.mom[0],self.player_maxscore,self.player_maxwickets,self.total_run2,self.total_wickets_loss2,self.total_over2
                else:
                    print("Match is Draw")
                    return "Match is Draw"
    def tournament(self):
        self.a = []
        self.tour = []
        self.mom2 = []
        for i in range(1,4):
            print(f"Match {i} of Touranament")
            print("---------------------------------------------------------------------------------------------------")
            b = self.match1()
            print(b)
            self.a.append(b)
            if self.a[-1][0]==1:
                    print(f"Team 1 won \n{self.a[-1][1]} is the man of the match")
                    self.mom2.append(self.a[-1][1])
                    print("---------------------------------------------------------------------------------------------------")
                    self.tour.append("team1")
            elif self.a[-1][0]==2:
                    print(f"Team 2 won\n{self.a[-1][1]} is the man of the match")
                    self.mom2.append(self.a[-1][1])
                    print("---------------------------------------------------------------------------------------------------")
                    self.tour.append("team2")
            else:
                self.tour.append("draw")
        if self.tour.count("team1")> self.tour.count("team2"):
            print(f"Team1 won the Tounament")
            if self.mom2.count(self.mom2[0]) > self.mom2.count(self.mom2[1]):
                print(f"{self.mom2[0]} is The Man of Tournament")
            elif self.mom2.count(self.mom2[1]) > self.mom2.count(self.mom2[0]):
                print(f"{self.mom2[1]} is The Man of Tournament")
            else:
                print(f"{self.mom2[2]} is The Man of Tournament")
        elif self.tour.count("team1")<self.tour.count("team2"):
            print(f"Team2 won the Tounament")
            if self.mom2.count(self.mom2[0]) > self.mom2.count(self.mom2[1]):
                print(f"{self.mom2[0]} is The Man of Tournament")
            elif self.mom2.count(self.mom2[1]) > self.mom2.count(self.mom2[0]):
                print(f"{self.mom2[1]} is The Man of Tournament")
            elif self.mom2.count(self.mom2[1]) > self.mom2.count(self.mom2[0]):
                print(f"{self.mom2[2]} is The Man of Tournament")
        else:
            print("Tournament is Level")

# %%
#i AM JUST ENTERING 3 PLAYERS NAME IN EACH TEAM,BECUASE NOT AS MUCH TIME TO TYPE 11 PLAYER NAME 3 TIMES.

a = Match()

a.tournament()
# Out:
# Match 1 of Touranament
# ---------------------------------------------------------------------------------------------------
# **************************************************************************************************
# Team1 Enter player name and his role like Batsman/Bowler/Allrounder comma seprated FAKHAR,BATSMAN
# Team1 Enter player name and his role like Batsman/Bowler/Allrounder comma seprated BABAR,BATSMAN
# Team1 Enter player name and his role like Batsman/Bowler/Allrounder comma seprated AMIR,BOWLER
# ---------------------------------------------------------------------------------------------------
# Team2 Enter player name and his role like Batsman/Bowler/Allrounder comma seprated ROHIT,BATSMAN
# Team2 Enter player name and his role like Batsman/Bowler/Allrounder comma seprated VIRAT,BATSMAN
# Team2 Enter player name and his role like Batsman/Bowler/Allrounder comma seprated BUMRAH,BOWLER
# ...

# %%
a = [(1, 'AMIL', {'AMIL': [96]}, {}, 101, 2, 20)]

print(a[-1][2].get(a[-1][1]))
# Out:
# {'AMIL': [96]}

# %%
{self.a[-1][2].get(self.a[-1][1]
 by {self.a[-1][3].get(a[-1][1])} wickets
# Out:
# 'AMIL'

# %%
b = ["a","a","n"]
b.count(b[0])
# Out:
# 2

# %%
length = 5
maxwickets = {"a":3}
maxscore = {"b":40}
mom = []

print(len(maxscore))
# Out:
# 1

# %%
class P:
    def get_data(self):
        self.team1 = {"a":"bowl","b":"bat"}
class N(P):
    
    def mom2(self):
        for i,v in self.player_maxwickets.items():
            for c,d in self.player_maxscore.items():
                if v>=(len(self.team1)/2) and d<100:
                    self.mom.append(i)
                elif v<(len(self.team1)/2) and d>=100:
                    self.mom.append(c)
                elif v>(len(self.team1)/2) and d>=100:
                    self.mom.append(i)
                elif v<(len(self.team1)/2) and d>=50:
                    self.mom.append(c)
                elif v == 3 and d<50:
                    self.mom.append(i)
                else:
                    self.mom.append(c)
                print(v<(len(self.team1)/2))
    def b(self):
        super(N,self).get_data()
        self.mom = []
        self.player_maxwickets = {"a":1}
        self.player_maxscore = {"b":150}
        self.mom2()
        print(self.mom)
        
n = N()
n.b()
# Out:
# False
# ['b']

# %%
import random
class Team():
    def get_data(self):
        self.team1 = {}
        self.team2 = {}
        print("**************************************************************************************************")
        for i in range(0,2):
            ask1,ask2 = input("Team1 Enter player name and his role like Batsman/Bowler/Allrounder comma seprated ").split(",")
            self.team1[ask1] = ask2
        print("---------------------------------------------------------------------------------------------------")
        for i in range(0,2):
            ask1,ask2 = input("Team2 Enter player name and his role like Batsman/Bowler/Allrounder comma seprated ").split(",")
            self.team2[ask1] = ask2
        print("**************************************************************************************************")
        
class Match(Team):
    def mom1(self):
        for i,v in self.player_maxwickets.items():
            for c,d in self.player_maxscore.items():
                if v >=(len(self.team1)/2) and d<100:
                    self.mom.append(i)
                elif v<(len(self.team1)/2) and d>=100:
                    self.mom.append(c)
                elif v>(len(self.team1)/2) and d>=100:
                    self.mom.append(i)
                elif v<(len(self.team1)/2) and d>=50:
                    self.mom.append(c)
                elif v == 3 and d<50:
                    self.mom.append(i)
                else:
                    self.mom.append(c)
                print(self.player_maxscore,self.player_maxwickets)
    def match1(self):
        super(Match,self).get_data()
        toss = input("Team 1 what you want to choose for toss Heads of Tails ")
        print("---------------------------------------------------------------------------------------------------")
        if random.choice(("h")) == toss[0].lower():
            print(f"Its {toss} Team 1 won the toss")
            ask2 = input("Enter whats you wnat to do Bat/Bowl ")
            print("---------------------------------------------------------------------------------------------------")
            if ask2[0:3].lower() == "bat" :
                print("Team 1 is Batting First")
                self.team1_score = {}
                self.team1_wickets_takes = {}
                for i in self.team1.keys():
                    score1 = int(input(f"Enter score of Team 1 {i} "))
                    self.team1_score[i] = score1 
                print("---------------------------------------------------------------------------------------------------")
                for i,v in self.team1.items():
                    if v[:4].lower() == "bowl":
                        wickets = int(input(f"Enter No of wickets of Team1 {i} takes "))
                        self.team1_wickets_takes[i] = wickets
                self.total_wickets_loss1 = int(input("How many Wickets team1 loss after batting : "))
                self.total_over1 = int(input("In How many overs team 1 cover this target after batting : "))
                self.total_run1 = sum(self.team1_score.values())
                print("**************************************************************************************************")
                self.team2_score = {}
                self.team2_wickets_takes = {}
                for i in self.team2.keys():
                    score1 = int(input(f"Enter score of Team 2 {i} "))
                    self.team2_score[i] = score1 
                print("---------------------------------------------------------------------------------------------------")
                for i,v in self.team2.items():
                    if v[:4].lower() == "bowl":
                        wickets = int(input(f"Enter No of wickets of Team2 {i} takes "))
                        self.team2_wickets_takes[i] = wickets
                self.total_wickets_loss2 = sum(self.team1_wickets_takes.values())
                self.total_over2 = int(input("In How many overs team 2 cover this target after batting : "))
                self.total_run2 = sum(self.team2_score.values())
                if self.total_run1> self.total_run2 :
                    print("Team 1 win")
                    self.mom = []
                    self.player_maxscore = {}
                    self.player_maxwickets = {}
                    for i,v in self.team1_wickets_takes.items():
                        if v == max(self.team1_wickets_takes.values()):
                            self.player_maxwickets[i]  = [v]
                    for i,v in self.team1_score.items():
                        if v == max(self.team1_score.values()):
                            self.player_maxscore[i]  = [v]
                    self.mom1()
                    w=1
                    return w,self.mom,self.player_maxscore,self.player_maxwickets,self.total_run1,self.total_wickets_loss1,self.total_over1
                elif self.total_run1<self.total_run2: 
                    print("Team 2 win")
                    self.player_maxwickets = {}
                    self.player_maxscore = {}
                    self.mom = []
                    for i,v in self.team2_wickets_takes.items():
                        if v == max(self.team2_wickets_takes.values()):
                            self.player_maxwickets[i]  = [v]
                    for i,v in self.team2_score.items():
                        if v == max(self.team2_score.values()):
                            self.player_maxscore[i]  = [v]
                    print(self.team2_score,self.team2_wickets_takes)
                    print(self.player_maxscore,self.player_maxwickets)

# %%
a = Match()
a.match1()
# Out:
# **************************************************************************************************
# Team1 Enter player name and his role like Batsman/Bowler/Allrounder comma seprated dbchb,bat
# Team1 Enter player name and his role like Batsman/Bowler/Allrounder comma seprated hdbch,bowler
# ---------------------------------------------------------------------------------------------------
# Team2 Enter player name and his role like Batsman/Bowler/Allrounder comma seprated hsbdc,bat
# Team2 Enter player name and his role like Batsman/Bowler/Allrounder comma seprated njdbn,bowler
# **************************************************************************************************
# Team 1 what you want to choose for toss Heads of Tails h
# ---------------------------------------------------------------------------------------------------
# Its h Team 1 won the toss
# Enter whats you wnat to do Bat/Bowl bat
# ...

# %%
if self.a[-1][0]==1:
                if len(self.a[-1][3])==0:
                    print(f"Team 1 won by\n{self.a[-1][0]} is the man of the match")
                    self.mom2.append(self.a[-1][0])
                    print("---------------------------------------------------------------------------------------------------")
                else:
                    print(f"Team 1 won by\n{self.a[-1][0]} is the man of the match by ")
                    self.mom2.append(self.a[-1][0])
                self.tour.append("team1")
            elif self.a[-1][0]==2:
                if len(self.a[-1][3])==0:
                    print(f"Team 2 won by\n{self.a[-1][0]} is the man of the match by )} runs")
                    self.mom2.append(self.a[-1][0])
                    print("---------------------------------------------------------------------------------------------------")
                else:
                    print(f"Team 2 won by\n{self.a[-1][1]} is the man of the match")
                    self.mom2.append(self.a[-1][1])
                self.tour.append("team2")
            else:
# Out:
#   File "<tokenize>", line 10
#     elif self.a[-1][0]==2:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
for i in range(1,4):
        print(i)
# Out:
# 1
# 2
# 3
