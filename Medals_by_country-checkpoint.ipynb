# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

medals = pd.read_excel("medals.xlsx" , index_col=0)
medals = medals.dropna()
medals =  medals[0:10]
medals
# Out:
#                              Gold  Silver  Bronze
# Team (IOC code)
#  Algeria (ALG)                5.0     2.0     8.0
#  Argentina (ARG)             18.0    24.0    28.0
#  Armenia (ARM)                1.0     2.0     9.0
#  Australasia (ANZ) [ANZ]      3.0     4.0     5.0
#  Australia (AUS) [AUS] [Z]  140.0   152.0   177.0
#  Austria (AUT)               18.0    33.0    35.0
#  Azerbaijan (AZE)             6.0     6.0    15.0
#  Belarus (BLR)               12.0    24.0    39.0
#  Belgium (BEL)               37.0    52.0    53.0
#  Brazil (BRA)                23.0    30.0    55.0

# %%
fig , ax = plt.subplots()
ax.bar(medals.index , medals["Gold"])
plt.show()

# %%
fig , ax = plt.subplots()
ax.bar(medals.index , medals["Gold"])
ax.set_xticklabels(medals.index , rotation=90)
plt.show()

# %%
fig , ax = plt.subplots()
ax.bar(medals.index , medals["Gold"])
ax.set_xticklabels(medals.index , rotation=90)
ax.set_xlabel("Countries")
ax.set_ylabel("Medals")
plt.show()

# %%
fig , ax = plt.subplots()
ax.bar(medals.index , medals["Gold"])
ax.bar(medals.index , medals["Silver"] , bottom=medals["Gold"])
ax.set_xticklabels(medals.index , rotation=90)
ax.set_xlabel("Countries")
ax.set_ylabel("Medals")
plt.show()

# %%
fig , ax = plt.subplots()
ax.bar(medals.index , medals["Gold"])
ax.bar(medals.index , medals["Silver"] , bottom=medals["Gold"])
ax.bar(medals.index , medals["Bronze"] , bottom=medals["Gold"] + medals["Silver"])
ax.set_xticklabels(medals.index , rotation=90)
ax.set_xlabel("Countries")
ax.set_ylabel("Medals")
plt.show()

# %%
fig , ax = plt.subplots()
ax.bar(medals.index , medals["Gold"] , label="Gold" )
ax.bar(medals.index , medals["Silver"] , bottom=medals["Gold"] , label = "Silver")
ax.bar(medals.index , medals["Bronze"] , bottom=medals["Gold"] + medals["Silver"] , label = "Bronze")
ax.set_xticklabels(medals.index , rotation=90)
ax.set_xlabel("Countries")
ax.set_ylabel("Medals")
ax.legend()
plt.show()

# %%
weight = [70 , 65 , 68 , 78 , 60 , 45 , 49 , 56]
rest = [5 , 10 , 8 , 6 , 4 , 5 , 6 , 7]

# %%
fig , ax = plt.subplots()
ax.scatter(weight , rest)
plt.plot()
# Out:
# []
