# %%
import pandas as pd

# %%
df1 = pd.read_csv('dataset2.csv',encoding ="utf-8",sep='\t',delimiter=',')#, names = ['Descrption', 'Type'])
df1=df1.drop(df1.columns[df1.columns.str.contains('unnamed',case = False)],axis = 1)
df1['word_count'] = df1['Descrption'].apply(lambda x: len(str(x).split(" ")))
df1['char_count'] = df1['Descrption'].str.len()
df1[['Descrption','Type','word_count','char_count']].head()
delete = ['Weather','Violence','Sports','Politics','Operation','Information','Congres','Case','Arrest','Accident']
df2 = df1.loc[df1['Type'].isin(delete)]
df2
#df2[['Type','Descrption']].head()
#df1.head(5)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                 Date                                         Descrption  \
# 0      01-01-18 0:00  Ek khusosi ehmiayt ke hamil sal ka ikhtetam ho...
# 1      01-01-18 0:00  Allah ka shukar ada karna chaiye 2017 me insaf...
# 2      01-01-18 0:00  Khush amdeed 2018 khush amdeed 2018     [o'c  ...
# 3      01-01-18 0:00  Ek yadgar sal ka ikhtetam hogaya, Army Chief  ...
# 4      01-01-18 0:00  Mian Nawaz Sharif ki Awaam ko sal no ki mubara...
# 5      01-01-18 0:00  Karachi: Super Highway Tol Plaza par shadeed T...
# 7      01-01-18 0:00  Army Chief ka naye sal par paigam      [o'c   ...
# 8      01-01-18 0:00  Challenges ko mawaqai me tabdeel karegay, Army...
# 9      01-01-18 0:00  Lahore: Defence me Nakay par kharay Police Eha...
# 10     01-01-18 0:00  2018 ghair mamoli challenges ke sath intehai e...
# 11     01-01-18 0:00  Germany me naye sal 2018 ka agas shandar Aatis...
# 12     01-01-18 0:00  Army Chief General Qamar Javed Bajwa ka naye s...
# 13     01-01-18 0:00  Nawaz Sharif ka naye sal ke moqai par Qoum ko ...
# 14     01-01-18 0:00  Pakistan samait dunya bhur me naye sal ka shan...
# 15     01-01-18 0:00  Naye sal ke phele din se Petrol 4.06 rupay meh...
# 16     01-01-18 0:00  Mulk bhur me khushian bator Qoum hamare azam k...
# 17     01-01-18 0:00  Karachi me kayi sal bad sal no ki shab Seaview...
# 18     01-01-18 0:00  Faisalabad me naye sal ka Jashan manane walay ...
# 19     01-01-18 0:00  Lahore: Defence ke Elaqay me Taiz Raftar Gari ...
# 20     01-01-18 0:00  Naye sal ke agas par Mulk ke Mukhtalif Shahro ...
# 21     01-01-18 0:00  America kabhi bhi Shumali Korea ke khilaf Jung...
# 22     01-01-18 0:00  Lateni Amereci Mulk ko Starika me chota Tayyar...
# 23     01-01-18 0:00  Pakistan samait dunya bhur me Whatsap sarvice ...
# 24     01-01-18 0:00  Naya Sal_naya din_Petrol ki Qeemat bhi nayi!!!...
# 25     01-01-18 0:00  Saudi Arab: Petrolium Masoniyat ki Qeemato me ...
# 26     01-01-18 0:00  Nawaz Sharif ki Saudi Arab ke sath deal ki kha...
# 27     01-01-18 0:00  Saudi Arab ne Corruption ke khilaf Karwayi shu...
# 30     01-01-18 0:00  Pak Fouj ke Tarjuman ka naye sal ke agas par p...
# 33     01-01-18 0:00  Multan: Setal Mari Ijtemai Ziyadti Case ka 5 v...
# 35     01-01-18 0:00  Lahore: Wadat Colony Police ne Hawai Firing ka...
# 66176          87
# 66177          86
# 66178          98
# 66180         114
# 66181          84
# 66182          99
# 66183         132
# 66184         115
# 66185         148
# 66186         122
# 66187         100
# 66188         140
# 66189          93
# 66190         133
# 66191         148
# 66192         104
# 66193         108
# 66194         123
# 66195         112
# 66196         131
# 66198         109
#
# [57509 rows x 10 columns]

# %%
df1.sample(5, random_state=0)
# Out:
#                 Date                                         Descrption  \
# 57626  04-06-18 0:00  Battagram Ke Nale Main Nahane Wale 4 Bachay Do...
# 36807  31-03-18 0:00  Mudakhlaty Ka Tasavur Nahi Rakhta Humein Majbo...
# 2816   08-01-18 0:00  Karachi Ka Barhta Streate Crime___     [o'c   ...
# 25992  25-02-18 0:00  Ahad Cheema Ki Nishandahi Par Giriftariyan Shu...
# 21657  16-02-18 0:00  Mazi Mai Idary Faisly Karty Rahy Hain Wazir e ...
#
#                      Title                             Province        City  \
# 57626   DAWN Breaking News                   Khyber Pakhtunkhwa   Battagram
# 36807        Breaking News   Islamabad Capital Territory (ICT)   Islamabad
# 2816         Breaking News                                Sindh     Karachi
# 25992  DUNYA Breaking News                               Punjab      Lahore
# 21657    ARY Breaking News                               Punjab      Lahore
#
#               Title2     Tone         Type  word_count  char_count
# 57626  Breaking News  Nuetral     Accident          21          97
# 36807  Breaking News  Nuetral  Information          30         157
# 2816   Breaking News  Nuetral        Crime          14          62
# 25992  Breaking News  Nuetral  Information          17          77
# 21657  Breaking News  Nuetral     Politics          28         121

# %%
df2.groupby('Type').count()
# Out:
#               Date  Descrption  Title  Province   City  Title2   Tone  \
# Type
# Accident      1524        1524   1524      1524   1459    1524   1524
# Arrest        1319        1319   1319      1319   1239    1319   1319
# Case          8034        8034   8034      8034   7941    8034   8034
# Congres       1277        1277   1277      1277   1240    1277   1277
# Information  25665       25665  25665     25665  22081   25665  25665
# Operation     1819        1819   1819      1819   1757    1819   1819
# Politics     11491       11491  11491     11491  10582   11491  11491
# Sports        2074        2074   2074      2074   1516    2074   2074
# Violence      3249        3249   3249      3249   3050    3249   3249
# Weather       1057        1057   1057      1057    991    1057   1057
#
#              word_count  char_count
# Type
# Accident           1524        1524
# Arrest             1319        1319
# Case               8034        8034
# Congres            1277        1277
# Information       25665       25665
# Operation          1819        1819
# Politics          11491       11491
# Sports             2074        2074
# Violence           3249        3249
# Weather            1057        1057

# %%
'''''from collections import Counter

# dataframe of word counts per row
res = df2['Descrption'].str.split().apply(pd.value_counts)

# series of dictionaries of word counts, each series entry covering one row
res = df2['Descrption'].str.split().apply(Counter)

# list of dictionaries of word counts, each list item covering one row
res = [Counter(x) for x in df2['Descrption'].str.split()]
#y = df1.Series(' '.join(df1['Descrption']).lower().split()).value_counts()[:10]'''''
# Out:
# "''from collections import Counter\n\n# dataframe of word counts per row\nres = df2['Descrption'].str.split().apply(pd.value_counts)\n\n# series of dictionaries of word counts, each series entry covering one row\nres = df2['Descrption'].str.split().apply(Counter)\n\n# list of dictionaries of word counts, each list item covering one row\nres = [Counter(x) for x in df2['Descrption'].str.split()]\n#y = df1.Series(' '.join(df1['Descrption']).lower().split()).value_counts()[:10]"

# %%
print(df2.groupby('Type').size())
df2.Descrption.describe()
freq = pd.Series(' '.join(df2['Descrption']).split()).value_counts()[:5]
freq
# Out:
# Type
# Accident        1524
# Arrest          1319
# Case            8034
# Congres         1277
# Information    25665
# Operation       1819
# Politics       11491
# Sports          2074
# Violence        3249
# Weather         1057
# dtype: int64
# [o'c         57462
# None         19881
# Ke           17385
# Ki           16008
# Islamabad    13964
# dtype: int64

# %%
freq1 =  pd.Series(' '.join(df1 
         ['Descrption']).split()).value_counts()[-5:]
freq1
# Out:
# Chena,      1
# Comiite     1
# Kufail      1
# Taqurrio    1
# Rohail      1
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig = plt.figure(figsize=(8,6))
df2.groupby('Type').Descrption.count().plot.bar(ylim=0)
plt.show()

#data_count = df1.groupby('Type').count()
#plt.bar(data_count.index.values, data_count['Descrption'])
#plt.title("Total Count")
#plt.xlabel('Categories', fontsize=20)
#plt.ylabel('Total Count', fontsize=20)
#plt.show()

# %%
df2.Type.unique()
# Out:
# array(['Information', 'Politics', 'Accident', 'Operation', 'Arrest',
#        'Case', 'Sports', 'Violence', 'Congres', 'Weather'], dtype=object)

# %%
category_id_df = df2[['Descrption', 'Type']].drop_duplicates().sort_values('Type')
category_id_df
# Out:
#                                               Descrption      Type
# 15254  Nawabshah, Chemical Sy Bhary Tanker Ko Hadsa  ...  Accident
# 9884   Karachi : Northern Bypass Ke Qareeb Bus Or Tru...  Accident
# 21887  Shikarpur, Jail Chowrangi Bypass Ke Qareeb Tra...  Accident
# 61579  Layyah: Chowk Azam Par Ali Pur Se Islamabad Ja...  Accident
# 51798  Jhang : faisalabad Road Par Car Or Highes Ka T...  Accident
# 6025   Lahore: Kenal Road par Car ki Takar se Motercy...  Accident
# 6024   Amereci Riyasat California me Taiz Raftar Car ...  Accident
# 47802  Karachi : Quaiedabad Road Par Truck Ulat Gaya ...  Accident
# 22535  Umarkot: Rantoor Road par Taiz Raftari ke bas ...  Accident
# 27228  Chaman se Karachi jane wali Musafir Coach ko H...  Accident
# 47803  Koranghi Crossing Par Gari Darakht Se Takra Ga...  Accident
# 47807  Mulk Ke Mukhtalif Hisson Mein Traffic Hadsaat ...  Accident
# 29415  Tez Raftaar Dumper Jaan Le Gaya      [o'c    -...  Accident
# 21878  Islamabad : Maryam Nawaz Ke Kafly Mai Shamil G...  Accident
# 9863   Karachi : Northern Bypass Par Bus Or Truck Mai...  Accident
# 40352   Lahore: Naji Housing Society Ke Gate Se Track...  Accident
# 6019   Lahore me Kenal Road par Traffic Hadsa, Nojawa...  Accident
# 26010  Sadiqabad : Qomi Shahirah Par Truck Ki Motor C...  Accident
# 47817  Lahore : Litton Road PAr Truck Ki Zad Mein Aka...  Accident
# 1442   Sahiwal : Oil Tanker Ulatne Se Hazaron Litre T...  Accident
# 7189   Bhaolangar : Manchanabad Road Par Tractor Trol...  Accident
# 47818  Karachi : Korangi Crossing Ke Kareeb 2 Garion ...  Accident
# 6016   Lahore: Kenal Road par Gari ki Motercycle ko T...  Accident
# 61545  Kasur : Depalpur Road Par Traffic Hadsa, 3 Afr...  Accident

# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 0     0
# 1     1
# 2     0
# 3     0
# 4     1
# 5     0
# 7     0
# 8     0
# 9     2
# 10    0
# Name: category_id, dtype: int32

# %%
category_id_df = df2[['Type', 'category_id']].drop_duplicates().sort_values('category_id')

# %%
category_id_df
# Out:
#             Type  category_id
# 0    Information            0
# 1       Politics            1
# 9       Accident            2
# 33     Operation            3
# 35        Arrest            4
# 44          Case            5
# 81        Sports            6
# 98      Violence            7
# 401      Congres            8
# 417      Weather            9

# %%
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id','Type']].values)
id_to_category
# Out:
# {0: 'Information',
#  1: 'Politics',
#  2: 'Accident',
#  3: 'Operation',
#  4: 'Arrest',
#  5: 'Case',
#  6: 'Sports',
#  7: 'Violence',
#  8: 'Congres',
#  9: 'Weather'}

# %%
df2.sample(5, random_state=0)
# Out:
#                 Date                                         Descrption  \
# 35868  28-03-18 0:00  Chairman Nab Jawaid Iqbal Ki Zer Sadarat Nab E...
# 38251  05-04-18 0:00    Kaly Heran Ka Case Adalat Ne Salman Khan Ko ...
# 20635  14-02-18 0:00  America Ka Pakistan Ko Global Watch Dog Fehris...
# 29375  06-03-18 0:00  Chaman Mein CTD Ki Karvai, 4 Dehshatgardi Hala...
# 19405  11-02-18 0:00  Asma Jahangeer Doran Elaj Janbar Na Ho Sakien ...
#
#                      Title                             Province          City  \
# 35868        Breaking News   Islamabad Capital Territory (ICT)     Islamabad
# 38251     92 Breaking News                         --- None ---  --- None ---
# 20635    Neo Breaking News                         --- None ---  --- None ---
# 29375              24 News                          Balochistan        Chaman
# 19405  DUNYA Breaking News                               Punjab        Lahore
#
#               Title2     Tone         Type  word_count  char_count  \
# 35868  Breaking News  Nuetral      Congres          28         132
# 38251  Breaking News  Nuetral         Case          29         118
# 20635  Breaking News  Nuetral  Information          29         131
# 29375  Breaking News  Nuetral    Operation          18          82
# 19405  Breaking News  Nuetral  Information          18          74
#
#        category_id
# 35868            8
# 38251            5
# 20635            0
# 29375            3
# 19405            0

# %%
df2.groupby('Type').category_id.count()
# Out:
# Type
# Accident        1524
# Arrest          1319
# Case            8034
# Congres         1277
# Information    25665
# Operation       1819
# Politics       11491
# Sports          2074
# Violence        3249
# Weather         1057
# Name: category_id, dtype: int64

# %%
new_stopwords = ('a', "a's", 'able', 'about', 'above', 'according', 'accordingly',
              'across', 'actually', 'after', 'afterwards', 'again', 'against',
              "ain't", 'all', 'allow', 'allows', 'almost', 'alone', 'along',
              'already', 'also', 'although', 'always', 'am', 'among', 'amongst',
              'an', 'and', 'another', 'any', 'anybody', 'anyhow', 'anyone',
              'anything', 'anyway', 'anyways', 'anywhere', 'apart', 'appear',
              'appreciate', 'appropriate', 'are', "aren't", 'around', 'as',
              'aside', 'ask', 'asking', 'associated', 'at', 'available', 'away',
              'awfully', 'b', 'be', 'became', 'because', 'become', 'becomes',
              'becoming', 'been', 'before', 'beforehand', 'behind', 'being',
              'believe', 'below', 'beside', 'besides', 'best', 'better',
              'between', 'beyond', 'both', 'brief', 'but', 'by', 'c', "c'mon",
              "c's", 'came', 'can', "can't", 'cannot', 'cant', 'cause',
              'causes', 'certain', 'certainly', 'changes', 'clearly', 'co',
              'com', 'come', 'comes', 'concerning', 'consequently', 'consider',
              'considering', 'contain', 'containing', 'contains',
              'corresponding', 'could', "couldn't", 'course', 'currently', 'd',
              'definitely', 'described', 'despite', 'did', "didn't",
              'different', 'do', 'does', "doesn't", 'doing', "don't", 'done',
              'down', 'downwards', 'during', 'e', 'each', 'edu', 'eg', 'eight',
              'either', 'else', 'elsewhere', 'enough', 'entirely', 'especially',
              'et', 'etc', 'even', 'ever', 'every', 'everybody', 'everyone',
              'everything', 'everywhere', 'ex', 'exactly', 'example', 'except',
              'f', 'far', 'few', 'fifth', 'first', 'five', 'followed',
              'following', 'follows', 'for', 'former', 'formerly', 'forth',
              'four', 'from', 'further', 'furthermore', 'g', 'get', 'gets',
              'getting', 'given', 'gives', 'go', 'goes', 'going', 'gone', 'got',
              'gotten', 'greetings', 'h', 'had', "hadn't", 'happens', 'hardly',
              'has', "hasn't", 'have', "haven't", 'having', 'he', "he's",
              'hello', 'help', 'hence', 'her', 'here', "here's", 'hereafter',
              'hereby', 'herein', 'hereupon', 'hers', 'herself', 'hi', 'him',
              'himself', 'his', 'hither', 'hopefully', 'how', 'howbeit',
              'however', 'i', "i'd", "i'll", "i'm", "i've", 'ie', 'if',
              'ignored', 'immediate', 'in', 'inasmuch', 'inc', 'indeed',
              'indicate', 'indicated', 'indicates', 'inner', 'insofar',
              'instead', 'into', 'inward', 'is', "isn't", 'it', "it'd", "it'll",
              "it's", 'its', 'itself', 'j', 'just', 'k', 'keep', 'keeps',
              'kept', 'know', 'knows', 'known', 'l', 'last', 'lately', 'later',
              'latter', 'latterly', 'least', 'less', 'lest', 'let', "let's",
              'like', 'liked', 'likely', 'little', 'look', 'looking', 'looks',
              'ltd', 'm', 'mainly', 'many', 'may', 'maybe', 'me', 'mean',
              'meanwhile', 'merely', 'might', 'more', 'moreover', 'most',
              'mostly', 'much', 'must', 'my', 'myself', 'n', 'name', 'namely',
              'nd', 'near', 'nearly', 'necessary', 'need', 'needs', 'neither',
              'never', 'nevertheless', 'new', 'next', 'nine', 'no', 'nobody',
              'non', 'none', 'noone', 'nor', 'normally', 'not', 'nothing',
              'novel', 'now', 'nowhere', 'o', 'obviously', 'of', 'off', 'often',
              'oh', 'ok', 'okay', 'old', 'on', 'once', 'one', 'ones', 'only',
              'onto', 'or', 'other', 'others', 'otherwise', 'ought', 'our',
              'ours', 'ourselves', 'out', 'outside', 'over', 'overall', 'own',
              'p', 'particular', 'particularly', 'per', 'perhaps', 'placed',
              'please', 'plus', 'possible', 'presumably', 'probably',
              'provides', 'q', 'que', 'quite', 'qv', 'r', 'rather', 'rd', 're',
              'really', 'reasonably', 'regarding', 'regardless', 'regards',
              'relatively', 'respectively', 'right', 's', 'said', 'same', 'saw',
              'say', 'saying', 'says', 'second', 'secondly', 'see', 'seeing',
              'seem', 'seemed', 'seeming', 'seems', 'seen', 'self', 'selves',
              'sensible', 'sent', 'serious', 'seriously', 'seven', 'several',
              'shall', 'she', 'should', "shouldn't", 'since', 'six', 'so',
              'some', 'somebody', 'somehow', 'someone', 'something', 'sometime',
              'sometimes', 'somewhat', 'somewhere', 'soon', 'sorry',
              'specified', 'specify', 'specifying', 'still', 'sub', 'such',
              'sup', 'sure', 't', "t's", 'take', 'taken', 'tell', 'tends', 'th',
              'than', 'thank', 'thanks', 'thanx', 'that', "that's", 'thats',
              'the', 'their', 'theirs', 'them', 'themselves', 'then', 'thence',
              'there', "there's", 'thereafter', 'thereby', 'therefore',
              'therein', 'theres', 'thereupon', 'these', 'they', "they'd",
              "they'll", "they're", "they've", 'think', 'third', 'this',
              'thorough', 'thoroughly', 'those', 'though', 'three', 'through',
              'throughout', 'thru', 'thus', 'to', 'together', 'too', 'took',
              'toward', 'towards', 'tried', 'tries', 'truly', 'try', 'trying',
              'twice', 'two', 'u', 'un', 'under', 'unfortunately', 'unless',
              'unlikely', 'until', 'unto', 'up', 'upon', 'us', 'use', 'used',
              'useful', 'uses', 'using', 'usually', 'uucp', 'v', 'value',
              'various', 'very', 'via', 'viz', 'vs', 'w', 'want', 'wants',
              'was', "wasn't", 'way', 'we', "we'd", "we'll", "we're", "we've",
              'welcome', 'well', 'went', 'were', "weren't", 'what', "what's",
              'whatever', 'when', 'whence', 'whenever', 'where', "where's",
              'whereafter', 'whereas', 'whereby', 'wherein', 'whereupon',
              'wherever', 'whether', 'which', 'while', 'whither', 'who',
              "who's", 'whoever', 'whole', 'whom', 'whose', 'why', 'will',
              'willing', 'wish', 'with', 'within', 'without', "won't", 'wonder',
              'would', 'would', "wouldn't", 'x', 'y', 'yes', 'yet', 'you',
              "you'd", "you'll", "you're", "you've", 'your', 'yours',
              'yourself', 'yourselves', 'z', 'zero', '')

sw = ("kia","ho","rahy","o'c","_","mai","gaya","ga","kis","mere","tum","nai","tha","muje","kha","dil","dard","pata","nain")

punctuation = ('!','#','$','%','&','(',')','*','+','-','/','.',':',';','}','{',']','[','=','`','~','<','>','"','|','_',';')

preprocessing=new_stopwords + sw + punctuation

# %%
#int(len(X_train)*0.3)
#int(len(features) * 0.3)
#labels.shape
#print(features)
#y_train.shape
#print (X_train.shape, y_train.shape)
#print (X_test.shape, y_test.shape)
#print(y_test)
# Out:
# 35868    8
# 38251    5
# 20635    0
# 29375    3
# 19405    0
# 38484    0
# 23744    5
# 6742     0
# 5810     1
# 23573    7
# 9200     7
# 10022    1
# 43341    2
# 33176    1
# 24996    0
# 11369    0
# 40888    0
# 40941    0
# 19398    6
# 42745    9
# 29270    3
# 19086    1
# 7704     6
# 51194    5
# 18495    0
# 13226    0
# 23124    3
# 19934    0
# 1013     1
# 50081    2
#         ..
# 3442     0
# 56068    0
# 50326    5
# 52176    2
# 57604    0
# 38587    0
# 34391    6
# 24489    0
# 16171    0
# 15589    2
# 19937    0
# 28068    9
# 55503    8
# 33451    0
# 56496    5
# 13059    0
# 9724     1
# 66047    0
# 5202     0
# 13961    1
# 18121    0
# 26844    7
# 23324    0
# 22742    6
# 5456     5
# 32139    6
# 64925    1
# 14667    0
# 4766     4
# 53065    4
# Name: category_id, Length: 17253, dtype: int32

# %%
print(X_train_counts)
# Out:
#   (0, 17467)	2
#   (0, 6469)	1
#   (0, 22968)	1
#   (0, 8571)	1
#   (0, 20781)	1
#   (0, 12050)	1
#   (0, 22076)	1
#   (0, 8807)	1
#   (0, 18664)	1
#   (0, 17125)	1
#   (0, 21732)	1
#   (0, 21816)	1
#   (1, 11975)	1
#   (1, 19016)	1
#   (1, 11788)	1
#   (1, 8980)	1
#   (1, 17218)	1
#   (1, 435)	1
#   (1, 19789)	1
#   (1, 11315)	1
#   (1, 16064)	1
#   (1, 4277)	1
#   (1, 19230)	1
#   (1, 25542)	1
#   (1, 17125)	1
#   :	:
#   (40254, 14201)	1
#   (40254, 20322)	1
#   (40254, 12352)	1
#   (40254, 5397)	1
#   (40254, 9488)	1
#   (40254, 9773)	1
#   (40254, 21202)	1
#   (40254, 12733)	1
#   (40254, 17467)	2
#   (40255, 21726)	1
#   (40255, 9582)	1
#   (40255, 7309)	1
#   (40255, 12128)	1
#   (40255, 16496)	1
#   (40255, 21492)	1
#   (40255, 12234)	1
#   (40255, 9824)	1
#   (40255, 8684)	1
#   (40255, 21202)	1
#   (40255, 4659)	1
#   (40255, 9611)	1
#   (40255, 23964)	1
#   (40255, 4244)	1
#   (40255, 10234)	2
#   (40255, 12733)	3

# %%
from sklearn.model_selection import train_test_split
#sw = ["kia","ho","rahy","o'c","_","mai","gaya","ga","kis","mere","tum","nai","tha","muje","kha","dil","dard","pata","nain"]
from sklearn.feature_extraction.text import TfidfVectorizer
X_train, X_test, y_train, y_test = train_test_split(df2['Descrption'], df2['category_id'],test_size=0.3,random_state = 0)
tfidf = TfidfVectorizer(sublinear_tf=True, use_idf=True ,smooth_idf=False, min_df=3, norm='l2', encoding='utf-8', ngram_range=(1, 3), stop_words=preprocessing,max_features=700)

#features = tfidf.fit_transform(X_train).toarray()
#features = tfidf.fit_transform(df2.Descrption)
#features = np.array(features, dtype=object) 
features = tfidf.fit_transform(df2.Descrption).toarray()
#features = tfidf.fit_transform(X_train).toarray()
#features=tfidf.fit_transform(X_train)
labels = y_train
#labels = df2.category_id
#X_train.toarray()
#print(features)
#print(y_train)
print(features)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-110-138dc3bdc791> in <module>()
#       9 #features = tfidf.fit_transform(df2.Descrption)
#      10 #features = np.array(features, dtype=object)
# ---> 11 features = tfidf.fit_transform(df2.Descrption).toarray()
#      12 #features = tfidf.fit_transform(X_train).toarray()
#      13 #features=tfidf.fit_transform(X_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#     941         if out is None and order is None:
#     942             order = self._swap('cf')[0]
# --> 943         out = self._process_toarray_args(order, out)
#     944         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#     945             raise ValueError('Output array must be C or F contiguous')
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\base.py in _process_toarray_args(self, order, out)
#    1128             return out
#    1129         else:
# -> 1130             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1131
#    1132     def __numpy_ufunc__(self, func, method, pos, inputs, **kwargs):
#
# MemoryError:

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfTransformer
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
print(clf.predict(count_vect.transform(["Darja Hararat 44 Degree Tak Janay Ka Imkaan"])))
# Out:
# [9]

# %%
print(features.shape,labels.shape)
# Out:
# (40256, 1000) (40256,)

# %%
category_to_id.items()
# Out:
# dict_items([('Information', 0), ('Politics', 1), ('Accident', 2), ('Operation', 3), ('Arrest', 4), ('Case', 5), ('Sports', 6), ('Violence', 7), ('Congres', 8), ('Weather', 9)])

# %%
sorted(category_to_id.items())
# Out:
# [('Accident', 2),
#  ('Arrest', 4),
#  ('Case', 5),
#  ('Congres', 8),
#  ('Information', 0),
#  ('Operation', 3),
#  ('Politics', 1),
#  ('Sports', 6),
#  ('Violence', 7),
#  ('Weather', 9)]

# %%
# Use chi-square analysis to find corelation between features (importantce of words) and labels(news category) 
from sklearn.feature_selection import chi2
import numpy as np
#print(features)
N = 3  # We are going to look for top 3 categories
#For each category, find words that are highly corelated to it
for Category, category_id in sorted(category_to_id.items()):
  #print(labels) 
  #break
  features_chi2 = chi2(features, labels == category_id)                   # Do chi2 analyses of all items in this category
  #break
  indices = np.argsort(features_chi2[0])                                  # Sorts the indices of features_chi2[0] - the chi-squared stats of each feature
  feature_names = np.array(tfidf.get_feature_names())[indices]            # Converts indices to feature names ( in increasing order of chi-squared stat values)
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]         # List of single word features ( in increasing order of chi-squared stat values)
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]          # List for two-word features ( in increasing order of chi-squared stat values)
  print("# '{}':".format(Category))
  print("  . Most correlated unigrams:\n       . {}".format('\n       . '.join(unigrams[-N:]))) # Print 3 unigrams with highest Chi squared stat
  print("  . Most correlated bigrams:\n       . {}".format('\n       . '.join(bigrams[-N:]))) # Print 3 bigrams with highest Chi squared stat
  #print(features_chi2)
# Out:
# # 'Accident':
#   . Most correlated unigrams:
#        . bus
#        . musafir
#        . hadsa
#   . Most correlated bigrams:
#        . road par
#        . ke qareeb
#        . jan bahak
# # 'Arrest':
#   . Most correlated unigrams:
#        . griftar
#        . giriftar
#        . giraftar
#   . Most correlated bigrams:
#        . kar lia
#        . police ki
#        . ki karwai
# # 'Case':
#   . Most correlated unigrams:
#        . court
#        . case
#        . samat
#   . Most correlated bigrams:
#        . samat islamabad
#        . case ki
#        . ki samat
# # 'Congres':
#   . Most correlated unigrams:
#        . zer
#        . sadarat
#        . ijlas
#   . Most correlated bigrams:
#        . ki zer
#        . zer sadarat
#        . ka ijlas
# # 'Information':
#   . Most correlated unigrams:
#        . sharif
#        . case
#        . samat
#   . Most correlated bigrams:
#        . case ki
#        . samat islamabad
#        . ki samat
# # 'Operation':
#   . Most correlated unigrams:
#        . search
#        . karwayi
#        . operation
#   . Most correlated bigrams:
#        . police ka
#        . ki karwayi
#        . search operation
# # 'Politics':
#   . Most correlated unigrams:
#        . hain
#        . sharif
#        . nawaz
#   . Most correlated bigrams:
#        . farooq sattar
#        . imran khan
#        . nawaz sharif
# # 'Sports':
#   . Most correlated unigrams:
#        . psl
#        . cricket
#        . zealand
#   . Most correlated bigrams:
#        . pakistan ke
#        . pakistan ka
#        . pakistan ki
# # 'Violence':
#   . Most correlated unigrams:
#        . afrad
#        . tashadud
#        . firing
#         2.61600371e-001, 1.83267629e-001, 2.59915267e-001, 7.06701458e-002,
#         7.29720922e-002, 2.80901177e-001, 2.58197015e-002, 2.64305164e-002,
#         7.72162252e-001, 1.72920218e-001, 8.47342726e-008, 1.12920740e-001,
#         3.24653115e-001, 2.89125653e-001, 2.17812743e-001, 3.49112980e-001,
#         2.22736823e-001, 1.19390154e-001, 1.28992197e-001, 9.06433122e-002,
#         1.60905680e-001, 1.10858240e-004, 1.10858240e-004, 9.52034744e-005,
#         2.17621189e-001, 2.72555389e-001, 2.16275835e-001, 2.10600236e-001,
#         2.31430466e-001, 3.64877386e-001, 6.11142763e-001, 1.73900360e-001,
#         4.71371240e-001, 1.05964024e-001, 1.66073908e-001, 7.38541314e-002,
#         2.69684763e-001, 2.33530704e-001, 5.22770856e-001, 6.74417562e-001,
#         4.58963668e-001, 1.23013936e-001, 6.37901434e-001, 2.73621937e-001,
#         2.77694128e-001, 4.99964136e-001, 2.63385512e-001, 7.90475687e-002,
#         1.86466294e-001, 1.39033318e-003, 3.66142954e-002, 1.92189451e-001,
#         2.02581942e-002, 3.19814024e-001, 2.89926556e-001, 2.81519667e-001,
#         2.96349709e-001, 2.90591805e-001, 5.93072091e-002, 2.93108751e-001,
#         1.93770047e-001, 2.19242049e-001, 4.41880787e-001, 3.68057306e-001,
#         9.74224493e-002, 2.36810539e-001, 2.20271018e-001, 1.19295724e-001,
#         1.72509266e-001, 4.20780116e-001, 3.33739460e-001, 1.45203596e-001]))

# %%
from sklearn.manifold import TSNE

# Sampling a subset of our dataset because t-SNE is computationally expensive
#SAMPLE_SIZE = features.shape[])
#SAMPLE_SIZE = int(len(X_train) * 0.3)
SAMPLE_SIZE = int(len(features) * 0.3)
#SAMPLE_SIZE = int(len(features) * 0.3)
#print(len(y_train))
#SAMPLE_SIZE = 6000
#print(SAMPLE_SIZE)
np.random.seed(0)
indices = np.random.choice(range(len(features)), size=SAMPLE_SIZE, replace=False)          # Randomly select 30 % of samples
projected_features = TSNE(n_components=2, random_state=0).fit_transform(features[indices]) # Array of all projected features of 30% of Randomly chosen samples

# %%
type(projected_features)
# Out:
# numpy.ndarray

# %%
colors = ['pink', 'green', 'midnightblue', 'orange',  'black','darkgrey', 'blue','red','brown']
count=0
# Find points belonging to each category and plot them
for category, category_id in sorted(category_to_id.items()):
    points = projected_features[(labels[indices] == category_id).values]
    #print(points[:,0])
    count=count+1
    if count<=9:
        plt.scatter(points[:, 0], points[:, 1], s=30, c=colors[category_id], label=category)
        #break
plt.title("tf-idf feature vector for each sentece, projected on 2 dimensions.",
          fontdict=dict(fontsize=8))

plt.legend()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:696: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]

# %%
'''''from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import RidgeClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier


from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.linear_model import SGDClassifier


from sklearn.model_selection import cross_val_score

models = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=1),
    #LinearSVC(penalty="l2", dual=False, tol=1e-2),
    LinearSVC(C=1.0, class_weight=None, dual=False, fit_intercept=True,intercept_scaling=1, loss='squared_hinge', max_iter=1000,   multi_class='ovr', penalty='l2', random_state=None, tol=0.001,     verbose=0),
    MultinomialNB(),
    LogisticRegression(random_state=0),
    RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
        max_iter=None, normalize=False, random_state=None, solver='sag',
        tol=0.01),
    PassiveAggressiveClassifier(C=1.0, average=False, class_weight=None,
              early_stopping=False, fit_intercept=True, loss='hinge',
              max_iter=50, n_iter=None, n_iter_no_change=5, n_jobs=None,
              random_state=None, shuffle=True, tol=0.001,
              validation_fraction=0.1, verbose=0, warm_start=False),
    Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
      fit_intercept=True, max_iter=50, n_iter=None, n_iter_no_change=5,
      n_jobs=None, penalty=None, random_state=0, shuffle=True, tol=0.001,
      validation_fraction=0.1, verbose=0, warm_start=False),
    KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
           metric_params=None, n_jobs=None, n_neighbors=10, p=2,
           weights='uniform'),
    SGDClassifier(alpha=0.0001, average=False, class_weight=None,
       early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
       l1_ratio=0.15, learning_rate='optimal', loss='hinge', max_iter=50,
       n_iter=None, n_iter_no_change=5, n_jobs=None, penalty='l2',
       power_t=0.5, random_state=None, shuffle=True, tol=None,
       validation_fraction=0.1, verbose=0, warm_start=False),
    NearestCentroid(metric='euclidean', shrink_threshold=None)
]'''''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-8aff99b26261> in <module>()
#      28               max_iter=50, n_iter=None, n_iter_no_change=5, n_jobs=None,
#      29               random_state=None, shuffle=True, tol=0.001,
# ---> 30               validation_fraction=0.1, verbose=0, warm_start=False),
#      31     Perceptron(alpha=0.0001, class_weight=None, early_stopping=False, eta0=1.0,
#      32       fit_intercept=True, max_iter=50, n_iter=None, n_iter_no_change=5,
#
# TypeError: __init__() got an unexpected keyword argument 'early_stopping'

# %%
features.shape
# Out:
# (57509, 700)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import RidgeClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.linear_model import SGDClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier

models = [
    #MLPClassifier()
    MultinomialNB()
    #RandomForestClassifier(),
    #LinearSVC(),
    #LogisticRegression(),
    #RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
    #    max_iter=None, normalize=False, random_state=None, solver='sag',
    #    tol=0.01)
    #KNeighborsClassifier()
]

accuracy=[]
from sklearn.metrics import confusion_matrix
import scikitplot as skplt
count_vect = CountVectorizer()
tfidf_transformer = TfidfTransformer()
#tfidf = TfidfVectorizer(max_features=700,stop_words=preprocessing)
tfidf = TfidfVectorizer(sublinear_tf=True, use_idf=True ,smooth_idf=False, min_df=3, norm='l2', encoding='utf-8', ngram_range=(1, 3), stop_words=preprocessing,max_features=700)
#features = tfidf.fit_transform(df2.Descrption).toarray()
test_features = tfidf.fit_transform(X_test).toarray()

for model in models:
  #comment=['he is alien on earth']
  #X_test_counts = count_vect.fit_transform(X_test)
  #X_train_tfidf = tfidf_transformer.fit_transform(X_test_counts)
  model.fit(features, y_train)
  y_pred = model.predict(test_features)
  #comment=['he is alien on earth'] 
  #X_test_com = vect.transform(comment)
  #model_predicted=model.predict(X_test_com)
  #print(my_tags[model_predicted[0]])
  print('accuracy %s' % accuracy_score(y_pred, y_test))
  #accuracy.append(accuracy_score(y_pred, y_test));
  #print(classification_report(y_test, y_pred,target_names=my_tags))
  skplt.metrics.plot_confusion_matrix(y_test, y_pred, normalize=True)
  plt.show()
  #print(y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-e286ee31e63e> in <module>()
#      39   #X_test_counts = count_vect.fit_transform(X_test)
#      40   #X_train_tfidf = tfidf_transformer.fit_transform(X_test_counts)
# ---> 41   model.fit(features, y_train)
#      42   y_pred = model.predict(test_features)
#      43   #comment=['he is alien on earth']
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     577             Returns self.
#     578         """
# --> 579         X, y = check_X_y(X, y, 'csr')
#     580         _, n_features = X.shape
#     581
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     581         y = y.astype(np.float64)
#     582
# --> 583     check_consistent_length(X, y)
#     584
#     585     return X, y
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [57509, 40256]

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d')
plt.ylabel('Actual')
plt.xlabel('Predicted')
# Out:
# Text(0.5,15,'Predicted')

# %%
CV = 5  # Cross Validate with 5 different folds of 20% data ( 80-20 split with 5 folds )

#Create a data frame that will store the results for all 5 trials of the 3 different models
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = [] # Initially all entries are empty

# %%
#For each Algorithm 
for model in models:
  model_name = model.__class__.__name__
  # create 5 models with different 20% test sets, and store their accuracies
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  # Append all 5 accuracies into the entries list ( after all 3 models are run, there will be 3x5 = 15 entries)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))

# %%
# Store the entries into the results dataframe and name its columns    
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])
cv_df

# %%
import seaborn as sns

ax=sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df,size=8, jitter=True, edgecolor="gray", linewidth=2 )
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %%
cv_df.groupby('model_name').accuracy.mean()*100

# %%
from IPython.display import display

print(id_to_category)

for predicted in category_id_df.category_id:
  for actual in category_id_df.category_id:
    if predicted != actual and conf_mat[actual, predicted] >= 5:
      print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual], id_to_category[predicted], conf_mat[actual, predicted]))
      display(df2.loc[X_test[(y_test == actual) & (y_pred == predicted)]][['Type', 'Descrption']])
      print('')

# %%
texts = [" Muje aj nain khalina kune ke barish ho rahi hai",
         "Aj mosam karab hai",
         "50 afrad ka intiqal ho gaya zakmi hain",
         ]
text_features = tfidf.transform(texts)
predictions = model.predict(text_features)
for text, predicted in zip(texts, predictions):
  print('"{}"'.format(text))
  print("  - Predicted as: '{}'".format(id_to_category[predicted]))
  print("")
