# %%
import tensorflow as tf
import pandas as pd

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
mnist = tf.keras.datasets.fashion_mnist

# %%
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()

# %%
print(len(training_images))
# Out:
# 60000

# %%
print(len(test_images))
# Out:
# 10000

# %%
print(len(training_labels))
# Out:
# 60000

# %%
print(len(test_labels))
# Out:
# 10000

# %%
import matplotlib.pyplot as plt
#plot the first image in the dataset
plt.imshow(training_images[0])

# %%
import matplotlib.pyplot as plt
#plot the first image in the dataset
plt.imshow(training_images[10])
training_images.shape
# Out:
# (60000, 28, 28)

# %%
import matplotlib.pyplot as plt
#plot the first image in the dataset
plt.imshow(training_images[100])

# %%
import matplotlib.pyplot as plt
#plot the first image in the dataset
plt.imshow(training_images[25])

# %%
import matplotlib.pyplot as plt
#plot the first image in the dataset
plt.imshow(training_images[75])

# %%
import matplotlib.pyplot as plt
#plot the first image in the dataset
plt.imshow(training_images[605])

# %%
import matplotlib.pyplot as plt
#plot the first image in the dataset
plt.imshow(training_images[2999])

# %%
training_images  = training_images / 255.0

test_images = test_images / 255.0

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(),tf.keras.layers.Dense(128, activation=tf.nn.relu),tf.keras.layers.Dense(10, activation=tf.nn.softmax)])

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(),
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(training_images, training_labels, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 7s 121us/sample - loss: 0.4915 - accuracy: 0.8267
# Epoch 2/10
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.3737 - accuracy: 0.8656
# Epoch 3/10
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.3363 - accuracy: 0.8770
# Epoch 4/10
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.3101 - accuracy: 0.8868
# Epoch 5/10
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.2920 - accuracy: 0.8923
# Epoch 6/10
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.2778 - accuracy: 0.8973
# Epoch 7/10
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.2663 - accuracy: 0.8997
# Epoch 8/10
# 60000/60000 [==============================] - 6s 92us/sample - loss: 0.2553 - accuracy: 0.9051
# Epoch 9/10
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.2443 - accuracy: 0.9083
# Epoch 10/10
# 60000/60000 [==============================] - 6s 92us/sample - loss: 0.2354 - accuracy: 0.9108

# %%
model.evaluate(test_images, test_labels)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.34516458104848863, 0.8781]
