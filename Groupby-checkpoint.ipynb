# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('olympic.csv')

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
grouped=df.groupby('Sport')

# %%
df.groupby('Sport')

# %%
grouped.groups
# Out:
# {'Aeronautics': Int64Index([214105], dtype='int64'),
#  'Alpine Skiing': Int64Index([    59,     60,     61,     62,     63,     64,     65,     66,
#                  67,     68,
#              ...
#              270950, 270951, 270952, 270953, 270964, 270965, 270966, 270967,
#              271039, 271040],
#             dtype='int64', length=8829),
#  'Alpinism': Int64Index([ 30323,  30328,  32015,  45937,  60639,  60641,  69438, 142022,
#              147743, 163906, 164008, 172632, 173124, 213142, 213208, 218235,
#              218239, 218240, 218241, 218242, 218243, 218244, 224982, 230913,
#              255672],
#             dtype='int64'),
#  'Archery': Int64Index([   287,    659,    963,    964,   1054,   1475,   1476,   1488,
#                2093,   2094,
#              ...
#              267065, 267066, 267070, 267071, 267544, 268809, 268810, 268811,
#              268812, 269055],
#             dtype='int64', length=2334),
# ...

# %% [raw]
# grouped.get_group('Golf')

# %%
grouped.size()
# Out:
# Sport
# Aeronautics                      1
# Alpine Skiing                 8829
# Alpinism                        25
# Archery                       2334
# Art Competitions              3578
# Athletics                    38624
# Badminton                     1457
# Baseball                       894
# Basketball                    4536
# Basque Pelota                    2
# Beach Volleyball               564
# Biathlon                      4893
# Bobsleigh                     3058
# Boxing                        6047
# Canoeing                      6171
# Cricket                         24
# Croquet                         19
# Cross Country Skiing          9133
# Curling                        463
# Cycling                      10859
# Diving                        2842
# Equestrianism                 6344
# Fencing                      10735
# Figure Skating                2298
# Football                      6745
# Freestyle Skiing               937
# ...

# %%
grouped.get_group('Golf').count()
# Out:
# ID        247
# Name      247
# Sex       247
# Age       235
# Height    131
# Weight    108
# Team      247
# NOC       247
# Games     247
# Year      247
# Season    247
# City      247
# Sport     247
# Event     247
# Medal      46
# dtype: int64

# %%
df
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 9            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 10           6                     Per Knut Aaland   M  31.0   188.0    75.0
# ...

# %%
a=df.groupby(['Sport','City','Medal','Sex','Name',])

# %%
a.groups
# Out:
# {('Basketball',
#   'Barcelona',
#   nan,
#   'M',
#   'A Dijiang'): Int64Index([0], dtype='int64'),
#  ('Judo', 'London', nan, 'M', 'A Lamusi'): Int64Index([1], dtype='int64'),
#  ('Football',
#   'Antwerpen',
#   nan,
#   'M',
#   'Gunnar Nielsen Aaby'): Int64Index([2], dtype='int64'),
#  ('Tug-Of-War',
#   'Paris',
#   'Gold',
#   'M',
#   'Edgar Lindenau Aabye'): Int64Index([3], dtype='int64'),
#  ('Speed Skating',
#   'Calgary',
#   nan,
#   'F',
#   'Christine Jacoba Aaftink'): Int64Index([4, 5], dtype='int64'),
#  ('Speed Skating',
#   'Albertville',
#   nan,
#   'F',
#   'Christine Jacoba Aaftink'): Int64Index([6, 7], dtype='int64'),
#  ('Speed Skating',
#   'Lillehammer',
#   nan,
#   'F',
#   'Christine Jacoba Aaftink'): Int64Index([8, 9], dtype='int64'),
#  ('Cross Country Skiing',
#   'Albertville',
#   nan,
#   'M',
#   'Per Knut Aaland'): Int64Index([10, 11, 12, 13], dtype='int64'),
#  ('Cross Country Skiing',
#   'Lillehammer',
#   nan,
#   'M',
# ...

# %%
a=df.groupby(['Sport','City'])['Medal']

# %%
a

# %%
a.count()
# Out:
# Sport          City
# Aeronautics    Berlin                      1
# Alpine Skiing  Albertville                30
#                Calgary                    30
#                Cortina d'Ampezzo          18
#                Garmisch-Partenkirchen      6
#                Grenoble                   18
#                Innsbruck                  36
#                Lake Placid                18
#                Lillehammer                30
#                Nagano                     30
#                Oslo                       18
#                Salt Lake City             30
#                Sankt Moritz               19
#                Sapporo                    18
#                Sarajevo                   18
#                Sochi                      31
#                Squaw Valley               18
#                Torino                     30
#                Vancouver                  30
# Alpinism       Berlin                      2
# ...

# %%
b=df.groupby(['Sport','City', 'Medal'])

# %%
b

# %%
b.size()
# Out:
# Sport          City                    Medal
# Aeronautics    Berlin                  Gold       1
# Alpine Skiing  Albertville             Bronze     9
#                                        Gold      10
#                                        Silver    11
#                Calgary                 Bronze    10
#                                        Gold      10
#                                        Silver    10
#                Cortina d'Ampezzo       Bronze     6
#                                        Gold       6
#                                        Silver     6
#                Garmisch-Partenkirchen  Bronze     2
#                                        Gold       2
#                                        Silver     2
#                Grenoble                Bronze     6
#                                        Gold       6
#                                        Silver     6
#                Innsbruck               Bronze    11
# ...
