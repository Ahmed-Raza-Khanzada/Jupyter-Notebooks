# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.arange(0.0,2.0,0.01)
s = 1 + np.cos(2*np.pi*t)
plt.plot(t,s,"g")
plt.grid()
plt.xlabel("time")
plt.ylabel("voltage")
plt.title("cosine plot (cos(x))")
plt.show()
